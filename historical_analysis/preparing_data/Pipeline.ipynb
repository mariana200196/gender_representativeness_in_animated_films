# %% [markdown]
# This notebook analyses all of a film's frames and detects and classifies the animated faces using the trained detection and classification models. Film frames are sources from the website Animation Screencaps.
#
# To use Google Colab change the domain from 'github.com' to 'githubtocolab.com'. The notebook will open in Colab.

# %%
# !pip install torch==1.10.1+cu111 torchvision==0.11.2+cu111 torchaudio==0.10.1 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install pyyaml==5.1  > /dev/null
# !pip install detectron2 -f https://dl.fbaipublicfiles.com/detectron2/wheels/cu111/torch1.10/index.html

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Films
# !unzip "/content/drive/MyDrive/machine_learning/Films/*.zip" > /dev/null
# Detector
# !unzip /content/drive/MyDrive/machine_learning/Analysis/Detection_Test/Best_Detector.zip > /dev/null
# Classifier
# !unzip /content/drive/MyDrive/machine_learning/Analysis/Classification_Train_Test/Best_Classifier.zip > /dev/null

# %%
import glob as gb
import cv2
import pandas as pd
import os
import json
import itertools
import numpy as np
import matplotlib.pyplot as plt
import shutil

import detectron2
from detectron2.utils.logger import setup_logger
from detectron2.structures import BoxMode
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader, DatasetCatalog, MetadataCatalog

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, models, transforms
# from torchsummary import summary

# %%
film_list = []
for f in gb.glob('/content/[0-9]*'):
    film_list.append(f)
print(len(film_list), film_list[0])
# Out:
# 1 /content/8-ralphbreaks

# %%
mapping = {
    # Sequels
    "0-rescuers-down-under": "rescuers-2",
    "0-toy-story3": "toystory-3",
    "1-cars2": "cars-2",
    "3-monsters-university": "monstersinc-2",
    "6-finding-dory": "nemo-2",
    "7-cars3": "cars-3",
    "8-incredibles2": "incredibles-2",
    "8-ralphbreaks": "wreckitralph-2",
    "9-frozen2": "frozen-2",
    "9-toy-story2": "toystory-2",
    "9-toystory4": "toystory-4"
}

# %%
def get_board_dicts(dir):
    # Load the instances
    json_file = f"{dir}/instances.json"
    with open(json_file) as f:
        dataset_dicts = json.load(f)
    for i in dataset_dicts:
      fname = i["file_name"]
      i["file_name"] = f"{DATASET_PATH}/{fname}"
      # for j in i["annotations"]:
      #     j["bbox_mode"] = BoxMode.XYWH_ABS
      #     j["category_id"] = int(0)
      #     j["bbox"] = list(map(int, j["bbox"])) #something wrong here?
    return dataset_dicts

def register_datasets():
    for d in ["inference"]:
      DatasetCatalog.register(f"{FILM_NAME}", lambda d=d: get_board_dicts(f"{DATASET_PATH}")) 
      MetadataCatalog.get(f"{FILM_NAME}").set(thing_classes=["Face"]) # just "Face" if detection
      return

# %%
def get_matches(id, predictions):
  matches = [x for x in predictions if x["image_id"] == id]
  return matches

def lowest_conf_pred(pair):
  if pair[1]["score"] <= pair[0]["score"]:
    return pair[1]["image_id"], pair[1]["bbox"][0] # no id value to return :(
  else:
    return pair[0]["image_id"], pair[0]["bbox"][0]

def check_intersection(pairs):
  # Store prediction ids that are duplicate detections in image
  preds_to_remove = []
  for pair in pairs:
    # Calculate area of each bbox
    a_area = pair[0]["bbox"][2] * pair[0]["bbox"][3]
    b_area = pair[1]["bbox"][2] * pair[1]["bbox"][3]
    # Calculate intersection overlap
    # Bounding box format is [top-left-x, top-left-y, width, height]
    a_x1 = pair[0]["bbox"][0]
    a_y1 = pair[0]["bbox"][1]
    a_x2 = pair[0]["bbox"][0] + pair[0]["bbox"][2]
    a_y2 = pair[0]["bbox"][1] + pair[0]["bbox"][3]
    b_x1 = pair[1]["bbox"][0]
    b_y1 = pair[1]["bbox"][1]
    b_x2 = pair[1]["bbox"][0] + pair[1]["bbox"][2]
    b_y2 = pair[1]["bbox"][1] + pair[1]["bbox"][3]
    dx = min(a_x2, b_x2) - max(a_x1, b_x1)
    dy = min(a_y2, b_y2) - max(a_y1, b_y1)
    if (dx>=0) and (dy>=0):
      intersection = dx*dy
      # Is the intersection of either bbox area greater than 50%?
      a_overlap = intersection / a_area
      b_overlap = intersection / b_area
      if a_overlap >= 0.5 or b_overlap >= 0.5:
        image_id, bbox_x1 = lowest_conf_pred(pair)
        markers = (image_id, bbox_x1)
        preds_to_remove.append(markers)
    else:
      #print("No intersection")
      continue
  return(preds_to_remove)

# %%
for film in film_list:
  FILM_NAME = film.split("/")[-1]
  DATASET_PATH = f"/content/{FILM_NAME}/full"
  PRED_PATH = "/content/out"

  # Initialise dataframe for storing the output json
  output = pd.DataFrame(columns=["file_name","height","width","annotations"])
  output["annotations"] = output["annotations"].astype('object')
  # Loop through files
  fnames = [os.path.basename(f) for f in gb.glob(f"{DATASET_PATH}/*.jpg")]
  dims = cv2.imread(f"{DATASET_PATH}/{fnames[0]}").shape[:2]   # load first image to get dimensions
  for fname in fnames:
    # Entry for individual image and append to result
    res = pd.DataFrame(columns=["file_name","height","width","annotations"])
    res.at[0,"file_name"] = fname
    res.at[0,"height"] = dims[0]
    res.at[0,"width"] = dims[1]
    res["annotations"] = res["annotations"].astype('object')
    res.at[0,"annotations"] = []
    output = output.append(res)
    output.reset_index(drop=True,inplace=True)
  output.reset_index(inplace=True)
  output.rename(columns={"index": "image_id"}, inplace=True)
  output.to_json(f"{DATASET_PATH}/instances.json", orient="records")
  output.to_json(f"instances.json", orient="records") # copy saved in /content/ for easier debugging
  # Register dataset
  register_datasets()

  # Detect faces
  setup_logger()
  cfg = get_cfg()
  cfg.merge_from_file("output/config.yaml")
  cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7 # set threshold for this model
  cfg.MODEL.WEIGHTS = "output/model_final.pth"
  cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1 # "Face"
  predictor = DefaultPredictor(cfg)
  evaluator = COCOEvaluator(f"{FILM_NAME}", cfg, False, output_dir="./out/")
  test_loader = build_detection_test_loader(cfg, f"{FILM_NAME}")
  inference_on_dataset(predictor.model, test_loader, evaluator)

  # Remove duplicate detections
  with open(f"{PRED_PATH}/coco_instances_results.json") as f:
    predictions = json.load(f)
  ids = [x["image_id"] for x in predictions]
  unique_ids = list(set(ids))
  complete_list = []
  for id in unique_ids:
    # Get all predictions from 1 image
    matches = get_matches(id, predictions)
    # Sort the boxes from highest to lowest conf score
    matches.sort(key=lambda x: x["score"], reverse=True)
    # Create list with all unique pair-wise permutations
    pair_order_list = itertools.combinations(matches,2)
    pairs = list(pair_order_list)
    num_pairs = len(pairs)
    # Skip if only one prediction in image
    if num_pairs == 0:
      continue
    # Get predictions ids that are duplicate detections
    preds_to_remove = check_intersection(pairs)
    if len(preds_to_remove) > 0:
      # Add ids to remove
      complete_list.extend(preds_to_remove)
  unique_complete_list = list(set(complete_list))
  # Update predictions dict
  new_predictions = []
  for x in predictions:
    if (x["image_id"], x["bbox"][0]) not in unique_complete_list:
      new_predictions.append(x)
  print(f"Number of predictions remaining: {len(new_predictions)}/{len(predictions)}")
  # Save file
  os.rename(f"{PRED_PATH}/coco_instances_results.json", f"{PRED_PATH}/coco_instances_results_original.json")
  with open(f"{PRED_PATH}/coco_instances_results.json", 'w') as fp:
    json.dump(new_predictions, fp)

  # Crop faces
  predictions = pd.read_json(f"{PRED_PATH}/coco_instances_results.json") # Image_id comes from this file! Missing image_id's mean that no faces were detected in that image
  new = predictions.groupby(['image_id', 'category_id'], as_index = False).agg({'bbox': list, 'score': list})
  dataset_dicts = detectron2.data.datasets.load_coco_json(f"{PRED_PATH}/{FILM_NAME}_coco_format.json", f"{PRED_PATH}")
  for i in dataset_dicts:
      path = i["file_name"]
      fname = path.split("/")[-1]
      i["file_name"] = f"{DATASET_PATH}/{fname}" 
  img_ids = pd.DataFrame.from_dict(dataset_dicts)
  df = new.merge(img_ids, how="left")
  # Save to target folder
  DST_PATH = f"out/portraits"
  os.makedirs(f"{DST_PATH}", exist_ok=True)
  for index, row in df.iterrows():
    path = row["file_name"]
    fname = path.split("/")[-1]
    im_h = row["height"]
    im_w = row["width"]
    img = cv2.imread(path)
    for index, j in enumerate(row["bbox"]):
      bbox = j
      x1, y1, w, h = list(map(int, bbox)) # convert float annots to int
      # Increase the bbox size while ensuring it remains within image coordinates
      new_x1 = max(x1 - int(w*0.25), 0)
      new_y1 = max(y1 - int(h*0.5), 0)
      new_w = min(w + int(w*0.5), im_w)
      new_h = min(h + int(h*0.75), im_h)
      new_fname = fname.split(".jpg")[0] + "-" + str(index) + ".jpg"
      dst_path = f"{DST_PATH}/{new_fname}"
      #crop image
      crop_img = img[new_y1:new_y1+new_h, new_x1:new_x1+new_w]
      cv2.imwrite(dst_path, crop_img)
  num_imgs = len([name for name in os.listdir(f"/content/{DST_PATH}")])
  print(f"Done! Saved {num_imgs}")

  # Classify gender
  device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
  # Data transforms for inference
  data_transforms = { 
      'inference': transforms.Compose([ transforms.Resize((224, 224)),
                                      transforms.ToTensor(),
                                      # normalization is necessary for evaluation, because otherwise the model sees unexpecetd pixel colours
                                      transforms.Normalize([0.485, 0.456, 0.406], #ImageNet Mean
                                                            [0.229, 0.224, 0.225]) #ImageNet StdDev
      ])
  }
  # Create dataloader
  film_names = [FILM_NAME]
  image_datasets = {x: datasets.ImageFolder("out", data_transforms['inference']) for x in film_names}
  dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=1, shuffle=False, num_workers=2) for x in film_names}  # batch size 1 so can get file names correctly
  dataset_sizes = {x: len(image_datasets[x]) for x in film_names}
  # Class names
  class_names = ['female','male']
  # Load model
  model_name = 'model_best.pt'
  path_to_model = f'/content/output/{model_name}'
  model = torch.load(path_to_model)
  model.to(device)
  # Create temp dataframe to store predictions
  gender_preds = pd.DataFrame(columns=["portrait_file_name", "file_name", "portrait_id", "category_id"])
  # Make gender predictions and populate "category_id" with gender predictions
  with torch.no_grad():
    for x in film_names:
      for i, (inputs, labels) in enumerate(dataloaders[x]):
        inputs = inputs.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        path, _ = dataloaders[x].dataset.samples[i]
        fname = path.split('/')[-1]
        extension = fname.split('-')[-1]
        portrait_id = extension.split('.')[0]
        new_filename = f"{DATASET_PATH}/" + fname.split(f"-{extension}")[0] + ".jpg"
        for j in range(inputs.size()[0]):
          category_id = class_names[preds[j]]
        row = pd.DataFrame(
            [[path, new_filename, portrait_id, category_id]],
            columns=['portrait_file_name', 'file_name', 'portrait_id', 'category_id']
            )
        gender_preds = pd.concat([gender_preds, row])
      gender_preds.reset_index(drop=True, inplace=True)

  # Merge the dataframes "gender_preds" and "df"
  gender_preds = gender_preds.sort_values(by=['portrait_file_name']) # Sort path in descending order
  # Group the rows
  grouped_portraits = gender_preds.groupby(['file_name'], as_index = False).agg({'portrait_file_name': list, 'portrait_id': list, 'category_id': list})
  # Drop category_id column - it will be replaced by the one in gender_preds
  df = df.drop(['category_id'], axis=1)
  # Merge
  df_predictions = df.merge(grouped_portraits, how="left")
  df_predictions.to_csv(f'out/{FILM_NAME}_predictions.csv', index=False)

  # Save to drive
  shutil.make_archive(f"/content/drive/MyDrive/machine_learning/Analysis/Films/{mapping[FILM_NAME]}", 'zip', "./out")

  # Rename out dir
  os.rename("out", f"out-{mapping[FILM_NAME]}")
# Out:
# WARNING [09/22 11:19:46 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [09/22 11:19:46 d2.evaluation.coco_evaluation]: Trying to convert '8-ralphbreaks' to COCO format ...
# [09/22 11:19:46 d2.data.datasets.coco]: Converting annotations of dataset '8-ralphbreaks' to COCO format ...)
# [09/22 11:19:46 d2.data.datasets.coco]: Converting dataset dicts into COCO format
# [09/22 11:19:46 d2.data.datasets.coco]: Conversion finished, #images: 11981, #annotations: 0
# [09/22 11:19:46 d2.data.datasets.coco]: Caching COCO format annotations at './out/8-ralphbreaks_coco_format.json' ...
# [09/22 11:19:47 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |    Face    | 0            |
# |            |              |
# [09/22 11:19:47 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [09/22 11:19:47 d2.data.common]: Serializing 11981 elements to byte tensors and concatenating them all ...
# [09/22 11:19:47 d2.data.common]: Serialized dataset takes 1.87 MiB
# [09/22 11:19:47 d2.evaluation.evaluator]: Start inference on 11981 batches
# /usr/local/lib/python3.7/dist-packages/detectron2/structures/image_list.py:88: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   max_size = (max_size + (stride - 1)) // stride * stride
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [09/22 11:19:49 d2.evaluation.evaluator]: Inference done 11/11981. Dataloading: 0.0011 s/iter. Inference: 0.1205 s/iter. Eval: 0.0002 s/iter. Total: 0.1218 s/iter. ETA=0:24:17
# [09/22 11:19:54 d2.evaluation.evaluator]: Inference done 52/11981. Dataloading: 0.0013 s/iter. Inference: 0.1219 s/iter. Eval: 0.0002 s/iter. Total: 0.1235 s/iter. ETA=0:24:33
# [09/22 11:19:59 d2.evaluation.evaluator]: Inference done 92/11981. Dataloading: 0.0013 s/iter. Inference: 0.1226 s/iter. Eval: 0.0002 s/iter. Total: 0.1242 s/iter. ETA=0:24:36
# [09/22 11:20:04 d2.evaluation.evaluator]: Inference done 132/11981. Dataloading: 0.0014 s/iter. Inference: 0.1232 s/iter. Eval: 0.0002 s/iter. Total: 0.1249 s/iter. ETA=0:24:39
# [09/22 11:20:09 d2.evaluation.evaluator]: Inference done 172/11981. Dataloading: 0.0014 s/iter. Inference: 0.1237 s/iter. Eval: 0.0002 s/iter. Total: 0.1254 s/iter. ETA=0:24:40
# [09/22 11:20:14 d2.evaluation.evaluator]: Inference done 212/11981. Dataloading: 0.0014 s/iter. Inference: 0.1241 s/iter. Eval: 0.0002 s/iter. Total: 0.1258 s/iter. ETA=0:24:40
# [09/22 11:20:19 d2.evaluation.evaluator]: Inference done 251/11981. Dataloading: 0.0014 s/iter. Inference: 0.1245 s/iter. Eval: 0.0002 s/iter. Total: 0.1262 s/iter. ETA=0:24:40
# [09/22 11:20:24 d2.evaluation.evaluator]: Inference done 290/11981. Dataloading: 0.0014 s/iter. Inference: 0.1248 s/iter. Eval: 0.0002 s/iter. Total: 0.1266 s/iter. ETA=0:24:39
# [09/22 11:20:29 d2.evaluation.evaluator]: Inference done 329/11981. Dataloading: 0.0014 s/iter. Inference: 0.1252 s/iter. Eval: 0.0002 s/iter. Total: 0.1270 s/iter. ETA=0:24:39
# [09/22 11:20:34 d2.evaluation.evaluator]: Inference done 368/11981. Dataloading: 0.0014 s/iter. Inference: 0.1257 s/iter. Eval: 0.0002 s/iter. Total: 0.1274 s/iter. ETA=0:24:39
# [09/22 11:20:39 d2.evaluation.evaluator]: Inference done 406/11981. Dataloading: 0.0014 s/iter. Inference: 0.1261 s/iter. Eval: 0.0002 s/iter. Total: 0.1278 s/iter. ETA=0:24:39
# [09/22 11:20:44 d2.evaluation.evaluator]: Inference done 444/11981. Dataloading: 0.0014 s/iter. Inference: 0.1265 s/iter. Eval: 0.0002 s/iter. Total: 0.1282 s/iter. ETA=0:24:38
# [09/22 11:20:49 d2.evaluation.evaluator]: Inference done 482/11981. Dataloading: 0.0014 s/iter. Inference: 0.1270 s/iter. Eval: 0.0002 s/iter. Total: 0.1287 s/iter. ETA=0:24:39
# [09/22 11:20:54 d2.evaluation.evaluator]: Inference done 520/11981. Dataloading: 0.0014 s/iter. Inference: 0.1274 s/iter. Eval: 0.0002 s/iter. Total: 0.1291 s/iter. ETA=0:24:39
# [09/22 11:20:59 d2.evaluation.evaluator]: Inference done 557/11981. Dataloading: 0.0014 s/iter. Inference: 0.1278 s/iter. Eval: 0.0002 s/iter. Total: 0.1295 s/iter. ETA=0:24:39
# [09/22 11:21:04 d2.evaluation.evaluator]: Inference done 594/11981. Dataloading: 0.0014 s/iter. Inference: 0.1283 s/iter. Eval: 0.0002 s/iter. Total: 0.1300 s/iter. ETA=0:24:39
# [09/22 11:21:09 d2.evaluation.evaluator]: Inference done 631/11981. Dataloading: 0.0014 s/iter. Inference: 0.1287 s/iter. Eval: 0.0002 s/iter. Total: 0.1304 s/iter. ETA=0:24:40
# [09/22 11:21:15 d2.evaluation.evaluator]: Inference done 668/11981. Dataloading: 0.0014 s/iter. Inference: 0.1291 s/iter. Eval: 0.0002 s/iter. Total: 0.1308 s/iter. ETA=0:24:40
# [09/22 11:21:20 d2.evaluation.evaluator]: Inference done 704/11981. Dataloading: 0.0014 s/iter. Inference: 0.1296 s/iter. Eval: 0.0002 s/iter. Total: 0.1313 s/iter. ETA=0:24:40
# [09/22 11:21:25 d2.evaluation.evaluator]: Inference done 740/11981. Dataloading: 0.0014 s/iter. Inference: 0.1301 s/iter. Eval: 0.0002 s/iter. Total: 0.1318 s/iter. ETA=0:24:41
# [09/22 11:21:30 d2.evaluation.evaluator]: Inference done 776/11981. Dataloading: 0.0014 s/iter. Inference: 0.1306 s/iter. Eval: 0.0002 s/iter. Total: 0.1323 s/iter. ETA=0:24:42
# [09/22 11:21:35 d2.evaluation.evaluator]: Inference done 812/11981. Dataloading: 0.0014 s/iter. Inference: 0.1310 s/iter. Eval: 0.0002 s/iter. Total: 0.1327 s/iter. ETA=0:24:42
# [09/22 11:21:40 d2.evaluation.evaluator]: Inference done 848/11981. Dataloading: 0.0014 s/iter. Inference: 0.1314 s/iter. Eval: 0.0002 s/iter. Total: 0.1331 s/iter. ETA=0:24:41
# [09/22 11:21:45 d2.evaluation.evaluator]: Inference done 884/11981. Dataloading: 0.0014 s/iter. Inference: 0.1318 s/iter. Eval: 0.0002 s/iter. Total: 0.1335 s/iter. ETA=0:24:41
# [09/22 11:21:50 d2.evaluation.evaluator]: Inference done 919/11981. Dataloading: 0.0014 s/iter. Inference: 0.1322 s/iter. Eval: 0.0002 s/iter. Total: 0.1339 s/iter. ETA=0:24:41
# [09/22 11:21:55 d2.evaluation.evaluator]: Inference done 954/11981. Dataloading: 0.0014 s/iter. Inference: 0.1326 s/iter. Eval: 0.0002 s/iter. Total: 0.1343 s/iter. ETA=0:24:41
# [09/22 11:22:00 d2.evaluation.evaluator]: Inference done 989/11981. Dataloading: 0.0014 s/iter. Inference: 0.1330 s/iter. Eval: 0.0002 s/iter. Total: 0.1347 s/iter. ETA=0:24:40
# [09/22 11:22:05 d2.evaluation.evaluator]: Inference done 1025/11981. Dataloading: 0.0014 s/iter. Inference: 0.1332 s/iter. Eval: 0.0002 s/iter. Total: 0.1350 s/iter. ETA=0:24:38
# [09/22 11:22:11 d2.evaluation.evaluator]: Inference done 1061/11981. Dataloading: 0.0014 s/iter. Inference: 0.1335 s/iter. Eval: 0.0002 s/iter. Total: 0.1352 s/iter. ETA=0:24:36
# [09/22 11:22:16 d2.evaluation.evaluator]: Inference done 1097/11981. Dataloading: 0.0014 s/iter. Inference: 0.1337 s/iter. Eval: 0.0002 s/iter. Total: 0.1354 s/iter. ETA=0:24:33
# [09/22 11:22:21 d2.evaluation.evaluator]: Inference done 1133/11981. Dataloading: 0.0014 s/iter. Inference: 0.1339 s/iter. Eval: 0.0002 s/iter. Total: 0.1356 s/iter. ETA=0:24:31
# [09/22 11:22:26 d2.evaluation.evaluator]: Inference done 1169/11981. Dataloading: 0.0014 s/iter. Inference: 0.1341 s/iter. Eval: 0.0002 s/iter. Total: 0.1358 s/iter. ETA=0:24:28
# [09/22 11:22:31 d2.evaluation.evaluator]: Inference done 1205/11981. Dataloading: 0.0014 s/iter. Inference: 0.1343 s/iter. Eval: 0.0002 s/iter. Total: 0.1360 s/iter. ETA=0:24:25
# [09/22 11:22:36 d2.evaluation.evaluator]: Inference done 1241/11981. Dataloading: 0.0014 s/iter. Inference: 0.1345 s/iter. Eval: 0.0002 s/iter. Total: 0.1362 s/iter. ETA=0:24:22
# [09/22 11:22:41 d2.evaluation.evaluator]: Inference done 1277/11981. Dataloading: 0.0014 s/iter. Inference: 0.1346 s/iter. Eval: 0.0002 s/iter. Total: 0.1364 s/iter. ETA=0:24:19
# [09/22 11:22:46 d2.evaluation.evaluator]: Inference done 1313/11981. Dataloading: 0.0015 s/iter. Inference: 0.1348 s/iter. Eval: 0.0002 s/iter. Total: 0.1365 s/iter. ETA=0:24:16
# [09/22 11:22:52 d2.evaluation.evaluator]: Inference done 1349/11981. Dataloading: 0.0015 s/iter. Inference: 0.1350 s/iter. Eval: 0.0002 s/iter. Total: 0.1367 s/iter. ETA=0:24:13
# [09/22 11:22:57 d2.evaluation.evaluator]: Inference done 1385/11981. Dataloading: 0.0015 s/iter. Inference: 0.1351 s/iter. Eval: 0.0002 s/iter. Total: 0.1368 s/iter. ETA=0:24:09
# [09/22 11:23:02 d2.evaluation.evaluator]: Inference done 1421/11981. Dataloading: 0.0014 s/iter. Inference: 0.1352 s/iter. Eval: 0.0002 s/iter. Total: 0.1370 s/iter. ETA=0:24:06
# [09/22 11:23:07 d2.evaluation.evaluator]: Inference done 1457/11981. Dataloading: 0.0015 s/iter. Inference: 0.1354 s/iter. Eval: 0.0002 s/iter. Total: 0.1371 s/iter. ETA=0:24:02
# [09/22 11:23:12 d2.evaluation.evaluator]: Inference done 1493/11981. Dataloading: 0.0015 s/iter. Inference: 0.1355 s/iter. Eval: 0.0002 s/iter. Total: 0.1372 s/iter. ETA=0:23:59
# [09/22 11:23:17 d2.evaluation.evaluator]: Inference done 1529/11981. Dataloading: 0.0015 s/iter. Inference: 0.1356 s/iter. Eval: 0.0002 s/iter. Total: 0.1373 s/iter. ETA=0:23:55
# [09/22 11:23:22 d2.evaluation.evaluator]: Inference done 1565/11981. Dataloading: 0.0015 s/iter. Inference: 0.1357 s/iter. Eval: 0.0002 s/iter. Total: 0.1374 s/iter. ETA=0:23:51
# [09/22 11:23:27 d2.evaluation.evaluator]: Inference done 1601/11981. Dataloading: 0.0015 s/iter. Inference: 0.1358 s/iter. Eval: 0.0002 s/iter. Total: 0.1375 s/iter. ETA=0:23:47
# [09/22 11:23:32 d2.evaluation.evaluator]: Inference done 1637/11981. Dataloading: 0.0014 s/iter. Inference: 0.1359 s/iter. Eval: 0.0002 s/iter. Total: 0.1376 s/iter. ETA=0:23:43
# [09/22 11:23:38 d2.evaluation.evaluator]: Inference done 1673/11981. Dataloading: 0.0014 s/iter. Inference: 0.1360 s/iter. Eval: 0.0002 s/iter. Total: 0.1377 s/iter. ETA=0:23:39
# [09/22 11:23:43 d2.evaluation.evaluator]: Inference done 1709/11981. Dataloading: 0.0014 s/iter. Inference: 0.1361 s/iter. Eval: 0.0002 s/iter. Total: 0.1378 s/iter. ETA=0:23:35
# [09/22 11:23:48 d2.evaluation.evaluator]: Inference done 1745/11981. Dataloading: 0.0014 s/iter. Inference: 0.1362 s/iter. Eval: 0.0002 s/iter. Total: 0.1379 s/iter. ETA=0:23:31
# [09/22 11:23:53 d2.evaluation.evaluator]: Inference done 1781/11981. Dataloading: 0.0014 s/iter. Inference: 0.1363 s/iter. Eval: 0.0002 s/iter. Total: 0.1380 s/iter. ETA=0:23:27
# [09/22 11:23:58 d2.evaluation.evaluator]: Inference done 1817/11981. Dataloading: 0.0014 s/iter. Inference: 0.1364 s/iter. Eval: 0.0002 s/iter. Total: 0.1381 s/iter. ETA=0:23:23
# [09/22 11:24:03 d2.evaluation.evaluator]: Inference done 1853/11981. Dataloading: 0.0014 s/iter. Inference: 0.1364 s/iter. Eval: 0.0002 s/iter. Total: 0.1382 s/iter. ETA=0:23:19
# [09/22 11:24:08 d2.evaluation.evaluator]: Inference done 1889/11981. Dataloading: 0.0014 s/iter. Inference: 0.1365 s/iter. Eval: 0.0002 s/iter. Total: 0.1383 s/iter. ETA=0:23:15
# [09/22 11:24:13 d2.evaluation.evaluator]: Inference done 1925/11981. Dataloading: 0.0014 s/iter. Inference: 0.1366 s/iter. Eval: 0.0002 s/iter. Total: 0.1383 s/iter. ETA=0:23:11
# [09/22 11:24:19 d2.evaluation.evaluator]: Inference done 1961/11981. Dataloading: 0.0014 s/iter. Inference: 0.1367 s/iter. Eval: 0.0002 s/iter. Total: 0.1384 s/iter. ETA=0:23:06
# [09/22 11:24:24 d2.evaluation.evaluator]: Inference done 1997/11981. Dataloading: 0.0014 s/iter. Inference: 0.1367 s/iter. Eval: 0.0002 s/iter. Total: 0.1385 s/iter. ETA=0:23:02
# [09/22 11:24:29 d2.evaluation.evaluator]: Inference done 2033/11981. Dataloading: 0.0014 s/iter. Inference: 0.1368 s/iter. Eval: 0.0002 s/iter. Total: 0.1385 s/iter. ETA=0:22:58
# [09/22 11:24:34 d2.evaluation.evaluator]: Inference done 2069/11981. Dataloading: 0.0014 s/iter. Inference: 0.1369 s/iter. Eval: 0.0002 s/iter. Total: 0.1386 s/iter. ETA=0:22:53
# [09/22 11:24:39 d2.evaluation.evaluator]: Inference done 2105/11981. Dataloading: 0.0014 s/iter. Inference: 0.1369 s/iter. Eval: 0.0002 s/iter. Total: 0.1386 s/iter. ETA=0:22:49
# [09/22 11:24:44 d2.evaluation.evaluator]: Inference done 2141/11981. Dataloading: 0.0014 s/iter. Inference: 0.1370 s/iter. Eval: 0.0002 s/iter. Total: 0.1387 s/iter. ETA=0:22:44
# [09/22 11:24:49 d2.evaluation.evaluator]: Inference done 2177/11981. Dataloading: 0.0014 s/iter. Inference: 0.1370 s/iter. Eval: 0.0002 s/iter. Total: 0.1388 s/iter. ETA=0:22:40
# [09/22 11:24:54 d2.evaluation.evaluator]: Inference done 2213/11981. Dataloading: 0.0014 s/iter. Inference: 0.1371 s/iter. Eval: 0.0002 s/iter. Total: 0.1388 s/iter. ETA=0:22:36
# [09/22 11:25:00 d2.evaluation.evaluator]: Inference done 2249/11981. Dataloading: 0.0014 s/iter. Inference: 0.1372 s/iter. Eval: 0.0002 s/iter. Total: 0.1389 s/iter. ETA=0:22:31
# [09/22 11:25:05 d2.evaluation.evaluator]: Inference done 2285/11981. Dataloading: 0.0014 s/iter. Inference: 0.1372 s/iter. Eval: 0.0002 s/iter. Total: 0.1389 s/iter. ETA=0:22:27
# [09/22 11:25:10 d2.evaluation.evaluator]: Inference done 2321/11981. Dataloading: 0.0014 s/iter. Inference: 0.1373 s/iter. Eval: 0.0002 s/iter. Total: 0.1390 s/iter. ETA=0:22:22
# [09/22 11:25:15 d2.evaluation.evaluator]: Inference done 2357/11981. Dataloading: 0.0014 s/iter. Inference: 0.1373 s/iter. Eval: 0.0002 s/iter. Total: 0.1390 s/iter. ETA=0:22:17
# [09/22 11:25:20 d2.evaluation.evaluator]: Inference done 2393/11981. Dataloading: 0.0014 s/iter. Inference: 0.1373 s/iter. Eval: 0.0002 s/iter. Total: 0.1391 s/iter. ETA=0:22:13
# [09/22 11:25:25 d2.evaluation.evaluator]: Inference done 2429/11981. Dataloading: 0.0014 s/iter. Inference: 0.1374 s/iter. Eval: 0.0002 s/iter. Total: 0.1391 s/iter. ETA=0:22:08
# [09/22 11:25:30 d2.evaluation.evaluator]: Inference done 2465/11981. Dataloading: 0.0014 s/iter. Inference: 0.1374 s/iter. Eval: 0.0002 s/iter. Total: 0.1392 s/iter. ETA=0:22:04
# [09/22 11:25:35 d2.evaluation.evaluator]: Inference done 2501/11981. Dataloading: 0.0014 s/iter. Inference: 0.1375 s/iter. Eval: 0.0002 s/iter. Total: 0.1392 s/iter. ETA=0:21:59
# [09/22 11:25:40 d2.evaluation.evaluator]: Inference done 2537/11981. Dataloading: 0.0014 s/iter. Inference: 0.1375 s/iter. Eval: 0.0002 s/iter. Total: 0.1392 s/iter. ETA=0:21:55
# [09/22 11:25:46 d2.evaluation.evaluator]: Inference done 2573/11981. Dataloading: 0.0014 s/iter. Inference: 0.1376 s/iter. Eval: 0.0002 s/iter. Total: 0.1393 s/iter. ETA=0:21:50
# [09/22 11:25:51 d2.evaluation.evaluator]: Inference done 2609/11981. Dataloading: 0.0014 s/iter. Inference: 0.1376 s/iter. Eval: 0.0002 s/iter. Total: 0.1393 s/iter. ETA=0:21:45
# [09/22 11:25:56 d2.evaluation.evaluator]: Inference done 2645/11981. Dataloading: 0.0014 s/iter. Inference: 0.1376 s/iter. Eval: 0.0002 s/iter. Total: 0.1394 s/iter. ETA=0:21:41
# [09/22 11:26:01 d2.evaluation.evaluator]: Inference done 2681/11981. Dataloading: 0.0014 s/iter. Inference: 0.1377 s/iter. Eval: 0.0002 s/iter. Total: 0.1394 s/iter. ETA=0:21:36
# [09/22 11:26:06 d2.evaluation.evaluator]: Inference done 2717/11981. Dataloading: 0.0014 s/iter. Inference: 0.1377 s/iter. Eval: 0.0002 s/iter. Total: 0.1394 s/iter. ETA=0:21:31
# [09/22 11:26:11 d2.evaluation.evaluator]: Inference done 2753/11981. Dataloading: 0.0014 s/iter. Inference: 0.1377 s/iter. Eval: 0.0002 s/iter. Total: 0.1395 s/iter. ETA=0:21:27
# [09/22 11:26:16 d2.evaluation.evaluator]: Inference done 2789/11981. Dataloading: 0.0014 s/iter. Inference: 0.1378 s/iter. Eval: 0.0002 s/iter. Total: 0.1395 s/iter. ETA=0:21:22
# [09/22 11:26:21 d2.evaluation.evaluator]: Inference done 2825/11981. Dataloading: 0.0014 s/iter. Inference: 0.1378 s/iter. Eval: 0.0002 s/iter. Total: 0.1395 s/iter. ETA=0:21:17
# [09/22 11:26:26 d2.evaluation.evaluator]: Inference done 2861/11981. Dataloading: 0.0014 s/iter. Inference: 0.1378 s/iter. Eval: 0.0002 s/iter. Total: 0.1396 s/iter. ETA=0:21:12
# [09/22 11:26:32 d2.evaluation.evaluator]: Inference done 2897/11981. Dataloading: 0.0014 s/iter. Inference: 0.1379 s/iter. Eval: 0.0002 s/iter. Total: 0.1396 s/iter. ETA=0:21:08
# [09/22 11:26:37 d2.evaluation.evaluator]: Inference done 2933/11981. Dataloading: 0.0014 s/iter. Inference: 0.1379 s/iter. Eval: 0.0002 s/iter. Total: 0.1396 s/iter. ETA=0:21:03
# [09/22 11:26:42 d2.evaluation.evaluator]: Inference done 2969/11981. Dataloading: 0.0014 s/iter. Inference: 0.1379 s/iter. Eval: 0.0002 s/iter. Total: 0.1397 s/iter. ETA=0:20:58
# [09/22 11:26:47 d2.evaluation.evaluator]: Inference done 3005/11981. Dataloading: 0.0014 s/iter. Inference: 0.1380 s/iter. Eval: 0.0002 s/iter. Total: 0.1397 s/iter. ETA=0:20:53
# [09/22 11:26:52 d2.evaluation.evaluator]: Inference done 3041/11981. Dataloading: 0.0014 s/iter. Inference: 0.1380 s/iter. Eval: 0.0002 s/iter. Total: 0.1397 s/iter. ETA=0:20:49
# [09/22 11:26:57 d2.evaluation.evaluator]: Inference done 3077/11981. Dataloading: 0.0014 s/iter. Inference: 0.1380 s/iter. Eval: 0.0002 s/iter. Total: 0.1398 s/iter. ETA=0:20:44
# [09/22 11:27:02 d2.evaluation.evaluator]: Inference done 3113/11981. Dataloading: 0.0014 s/iter. Inference: 0.1381 s/iter. Eval: 0.0002 s/iter. Total: 0.1398 s/iter. ETA=0:20:39
# [09/22 11:27:07 d2.evaluation.evaluator]: Inference done 3149/11981. Dataloading: 0.0014 s/iter. Inference: 0.1381 s/iter. Eval: 0.0002 s/iter. Total: 0.1398 s/iter. ETA=0:20:34
# [09/22 11:27:13 d2.evaluation.evaluator]: Inference done 3185/11981. Dataloading: 0.0014 s/iter. Inference: 0.1381 s/iter. Eval: 0.0002 s/iter. Total: 0.1398 s/iter. ETA=0:20:30
# [09/22 11:27:18 d2.evaluation.evaluator]: Inference done 3221/11981. Dataloading: 0.0014 s/iter. Inference: 0.1381 s/iter. Eval: 0.0002 s/iter. Total: 0.1399 s/iter. ETA=0:20:25
# [09/22 11:27:23 d2.evaluation.evaluator]: Inference done 3257/11981. Dataloading: 0.0014 s/iter. Inference: 0.1382 s/iter. Eval: 0.0002 s/iter. Total: 0.1399 s/iter. ETA=0:20:20
# [09/22 11:27:28 d2.evaluation.evaluator]: Inference done 3293/11981. Dataloading: 0.0014 s/iter. Inference: 0.1382 s/iter. Eval: 0.0002 s/iter. Total: 0.1399 s/iter. ETA=0:20:15
# [09/22 11:27:33 d2.evaluation.evaluator]: Inference done 3329/11981. Dataloading: 0.0014 s/iter. Inference: 0.1382 s/iter. Eval: 0.0002 s/iter. Total: 0.1399 s/iter. ETA=0:20:10
# [09/22 11:27:38 d2.evaluation.evaluator]: Inference done 3365/11981. Dataloading: 0.0014 s/iter. Inference: 0.1382 s/iter. Eval: 0.0002 s/iter. Total: 0.1400 s/iter. ETA=0:20:05
# [09/22 11:27:43 d2.evaluation.evaluator]: Inference done 3401/11981. Dataloading: 0.0014 s/iter. Inference: 0.1382 s/iter. Eval: 0.0002 s/iter. Total: 0.1400 s/iter. ETA=0:20:01
# [09/22 11:27:48 d2.evaluation.evaluator]: Inference done 3437/11981. Dataloading: 0.0014 s/iter. Inference: 0.1383 s/iter. Eval: 0.0002 s/iter. Total: 0.1400 s/iter. ETA=0:19:56
# [09/22 11:27:53 d2.evaluation.evaluator]: Inference done 3473/11981. Dataloading: 0.0014 s/iter. Inference: 0.1383 s/iter. Eval: 0.0002 s/iter. Total: 0.1400 s/iter. ETA=0:19:51
# [09/22 11:27:59 d2.evaluation.evaluator]: Inference done 3509/11981. Dataloading: 0.0014 s/iter. Inference: 0.1383 s/iter. Eval: 0.0002 s/iter. Total: 0.1400 s/iter. ETA=0:19:46
# [09/22 11:28:04 d2.evaluation.evaluator]: Inference done 3545/11981. Dataloading: 0.0014 s/iter. Inference: 0.1383 s/iter. Eval: 0.0002 s/iter. Total: 0.1401 s/iter. ETA=0:19:41
# [09/22 11:28:09 d2.evaluation.evaluator]: Inference done 3581/11981. Dataloading: 0.0014 s/iter. Inference: 0.1384 s/iter. Eval: 0.0002 s/iter. Total: 0.1401 s/iter. ETA=0:19:36
# [09/22 11:28:14 d2.evaluation.evaluator]: Inference done 3617/11981. Dataloading: 0.0014 s/iter. Inference: 0.1384 s/iter. Eval: 0.0002 s/iter. Total: 0.1401 s/iter. ETA=0:19:31
# [09/22 11:28:19 d2.evaluation.evaluator]: Inference done 3653/11981. Dataloading: 0.0014 s/iter. Inference: 0.1384 s/iter. Eval: 0.0002 s/iter. Total: 0.1401 s/iter. ETA=0:19:27
# [09/22 11:28:24 d2.evaluation.evaluator]: Inference done 3689/11981. Dataloading: 0.0014 s/iter. Inference: 0.1384 s/iter. Eval: 0.0002 s/iter. Total: 0.1402 s/iter. ETA=0:19:22
# [09/22 11:28:29 d2.evaluation.evaluator]: Inference done 3725/11981. Dataloading: 0.0014 s/iter. Inference: 0.1384 s/iter. Eval: 0.0002 s/iter. Total: 0.1402 s/iter. ETA=0:19:17
# [09/22 11:28:34 d2.evaluation.evaluator]: Inference done 3761/11981. Dataloading: 0.0014 s/iter. Inference: 0.1385 s/iter. Eval: 0.0002 s/iter. Total: 0.1402 s/iter. ETA=0:19:12
# [09/22 11:28:40 d2.evaluation.evaluator]: Inference done 3797/11981. Dataloading: 0.0014 s/iter. Inference: 0.1385 s/iter. Eval: 0.0002 s/iter. Total: 0.1402 s/iter. ETA=0:19:07
# [09/22 11:28:45 d2.evaluation.evaluator]: Inference done 3833/11981. Dataloading: 0.0014 s/iter. Inference: 0.1385 s/iter. Eval: 0.0002 s/iter. Total: 0.1402 s/iter. ETA=0:19:02
# [09/22 11:28:50 d2.evaluation.evaluator]: Inference done 3869/11981. Dataloading: 0.0014 s/iter. Inference: 0.1385 s/iter. Eval: 0.0002 s/iter. Total: 0.1402 s/iter. ETA=0:18:57
# [09/22 11:28:55 d2.evaluation.evaluator]: Inference done 3905/11981. Dataloading: 0.0014 s/iter. Inference: 0.1385 s/iter. Eval: 0.0002 s/iter. Total: 0.1403 s/iter. ETA=0:18:52
# [09/22 11:29:00 d2.evaluation.evaluator]: Inference done 3941/11981. Dataloading: 0.0014 s/iter. Inference: 0.1385 s/iter. Eval: 0.0002 s/iter. Total: 0.1403 s/iter. ETA=0:18:47
# [09/22 11:29:05 d2.evaluation.evaluator]: Inference done 3977/11981. Dataloading: 0.0014 s/iter. Inference: 0.1386 s/iter. Eval: 0.0002 s/iter. Total: 0.1403 s/iter. ETA=0:18:42
# [09/22 11:29:10 d2.evaluation.evaluator]: Inference done 4013/11981. Dataloading: 0.0014 s/iter. Inference: 0.1386 s/iter. Eval: 0.0002 s/iter. Total: 0.1403 s/iter. ETA=0:18:38
# [09/22 11:29:15 d2.evaluation.evaluator]: Inference done 4049/11981. Dataloading: 0.0014 s/iter. Inference: 0.1386 s/iter. Eval: 0.0002 s/iter. Total: 0.1403 s/iter. ETA=0:18:33
# [09/22 11:29:20 d2.evaluation.evaluator]: Inference done 4085/11981. Dataloading: 0.0014 s/iter. Inference: 0.1386 s/iter. Eval: 0.0002 s/iter. Total: 0.1404 s/iter. ETA=0:18:28
# [09/22 11:29:26 d2.evaluation.evaluator]: Inference done 4121/11981. Dataloading: 0.0014 s/iter. Inference: 0.1386 s/iter. Eval: 0.0002 s/iter. Total: 0.1404 s/iter. ETA=0:18:23
# [09/22 11:29:31 d2.evaluation.evaluator]: Inference done 4157/11981. Dataloading: 0.0014 s/iter. Inference: 0.1387 s/iter. Eval: 0.0002 s/iter. Total: 0.1404 s/iter. ETA=0:18:18
# [09/22 11:29:36 d2.evaluation.evaluator]: Inference done 4193/11981. Dataloading: 0.0014 s/iter. Inference: 0.1387 s/iter. Eval: 0.0002 s/iter. Total: 0.1404 s/iter. ETA=0:18:13
# [09/22 11:29:41 d2.evaluation.evaluator]: Inference done 4229/11981. Dataloading: 0.0014 s/iter. Inference: 0.1387 s/iter. Eval: 0.0002 s/iter. Total: 0.1404 s/iter. ETA=0:18:08
# [09/22 11:29:46 d2.evaluation.evaluator]: Inference done 4265/11981. Dataloading: 0.0014 s/iter. Inference: 0.1387 s/iter. Eval: 0.0002 s/iter. Total: 0.1404 s/iter. ETA=0:18:03
# [09/22 11:29:51 d2.evaluation.evaluator]: Inference done 4301/11981. Dataloading: 0.0014 s/iter. Inference: 0.1387 s/iter. Eval: 0.0002 s/iter. Total: 0.1404 s/iter. ETA=0:17:58
# [09/22 11:29:56 d2.evaluation.evaluator]: Inference done 4337/11981. Dataloading: 0.0014 s/iter. Inference: 0.1387 s/iter. Eval: 0.0002 s/iter. Total: 0.1405 s/iter. ETA=0:17:53
# [09/22 11:30:01 d2.evaluation.evaluator]: Inference done 4373/11981. Dataloading: 0.0014 s/iter. Inference: 0.1387 s/iter. Eval: 0.0002 s/iter. Total: 0.1405 s/iter. ETA=0:17:48
# [09/22 11:30:07 d2.evaluation.evaluator]: Inference done 4409/11981. Dataloading: 0.0014 s/iter. Inference: 0.1388 s/iter. Eval: 0.0002 s/iter. Total: 0.1405 s/iter. ETA=0:17:43
# [09/22 11:30:12 d2.evaluation.evaluator]: Inference done 4445/11981. Dataloading: 0.0014 s/iter. Inference: 0.1388 s/iter. Eval: 0.0002 s/iter. Total: 0.1405 s/iter. ETA=0:17:38
# [09/22 11:30:17 d2.evaluation.evaluator]: Inference done 4481/11981. Dataloading: 0.0014 s/iter. Inference: 0.1388 s/iter. Eval: 0.0002 s/iter. Total: 0.1405 s/iter. ETA=0:17:33
# [09/22 11:30:22 d2.evaluation.evaluator]: Inference done 4517/11981. Dataloading: 0.0014 s/iter. Inference: 0.1388 s/iter. Eval: 0.0002 s/iter. Total: 0.1405 s/iter. ETA=0:17:28
# [09/22 11:30:27 d2.evaluation.evaluator]: Inference done 4553/11981. Dataloading: 0.0014 s/iter. Inference: 0.1388 s/iter. Eval: 0.0002 s/iter. Total: 0.1405 s/iter. ETA=0:17:23
# [09/22 11:30:32 d2.evaluation.evaluator]: Inference done 4589/11981. Dataloading: 0.0014 s/iter. Inference: 0.1388 s/iter. Eval: 0.0002 s/iter. Total: 0.1406 s/iter. ETA=0:17:18
# [09/22 11:30:37 d2.evaluation.evaluator]: Inference done 4625/11981. Dataloading: 0.0014 s/iter. Inference: 0.1388 s/iter. Eval: 0.0002 s/iter. Total: 0.1406 s/iter. ETA=0:17:13
# [09/22 11:30:42 d2.evaluation.evaluator]: Inference done 4661/11981. Dataloading: 0.0014 s/iter. Inference: 0.1389 s/iter. Eval: 0.0002 s/iter. Total: 0.1406 s/iter. ETA=0:17:09
# [09/22 11:30:47 d2.evaluation.evaluator]: Inference done 4697/11981. Dataloading: 0.0014 s/iter. Inference: 0.1389 s/iter. Eval: 0.0002 s/iter. Total: 0.1406 s/iter. ETA=0:17:04
# [09/22 11:30:53 d2.evaluation.evaluator]: Inference done 4733/11981. Dataloading: 0.0014 s/iter. Inference: 0.1389 s/iter. Eval: 0.0002 s/iter. Total: 0.1406 s/iter. ETA=0:16:59
# [09/22 11:30:58 d2.evaluation.evaluator]: Inference done 4769/11981. Dataloading: 0.0014 s/iter. Inference: 0.1389 s/iter. Eval: 0.0002 s/iter. Total: 0.1406 s/iter. ETA=0:16:54
# [09/22 11:31:03 d2.evaluation.evaluator]: Inference done 4805/11981. Dataloading: 0.0014 s/iter. Inference: 0.1389 s/iter. Eval: 0.0002 s/iter. Total: 0.1406 s/iter. ETA=0:16:49
# [09/22 11:31:08 d2.evaluation.evaluator]: Inference done 4841/11981. Dataloading: 0.0014 s/iter. Inference: 0.1389 s/iter. Eval: 0.0002 s/iter. Total: 0.1406 s/iter. ETA=0:16:44
# [09/22 11:31:13 d2.evaluation.evaluator]: Inference done 4877/11981. Dataloading: 0.0014 s/iter. Inference: 0.1389 s/iter. Eval: 0.0002 s/iter. Total: 0.1406 s/iter. ETA=0:16:39
# [09/22 11:31:18 d2.evaluation.evaluator]: Inference done 4913/11981. Dataloading: 0.0014 s/iter. Inference: 0.1389 s/iter. Eval: 0.0002 s/iter. Total: 0.1407 s/iter. ETA=0:16:34
# [09/22 11:31:23 d2.evaluation.evaluator]: Inference done 4949/11981. Dataloading: 0.0014 s/iter. Inference: 0.1389 s/iter. Eval: 0.0002 s/iter. Total: 0.1407 s/iter. ETA=0:16:29
# [09/22 11:31:28 d2.evaluation.evaluator]: Inference done 4985/11981. Dataloading: 0.0014 s/iter. Inference: 0.1390 s/iter. Eval: 0.0002 s/iter. Total: 0.1407 s/iter. ETA=0:16:24
# [09/22 11:31:34 d2.evaluation.evaluator]: Inference done 5021/11981. Dataloading: 0.0014 s/iter. Inference: 0.1390 s/iter. Eval: 0.0002 s/iter. Total: 0.1407 s/iter. ETA=0:16:19
# [09/22 11:31:39 d2.evaluation.evaluator]: Inference done 5057/11981. Dataloading: 0.0014 s/iter. Inference: 0.1390 s/iter. Eval: 0.0002 s/iter. Total: 0.1407 s/iter. ETA=0:16:14
# [09/22 11:31:44 d2.evaluation.evaluator]: Inference done 5093/11981. Dataloading: 0.0014 s/iter. Inference: 0.1390 s/iter. Eval: 0.0002 s/iter. Total: 0.1407 s/iter. ETA=0:16:09
# [09/22 11:31:49 d2.evaluation.evaluator]: Inference done 5129/11981. Dataloading: 0.0014 s/iter. Inference: 0.1390 s/iter. Eval: 0.0002 s/iter. Total: 0.1407 s/iter. ETA=0:16:04
# [09/22 11:31:54 d2.evaluation.evaluator]: Inference done 5165/11981. Dataloading: 0.0014 s/iter. Inference: 0.1390 s/iter. Eval: 0.0002 s/iter. Total: 0.1407 s/iter. ETA=0:15:59
# [09/22 11:31:59 d2.evaluation.evaluator]: Inference done 5201/11981. Dataloading: 0.0014 s/iter. Inference: 0.1390 s/iter. Eval: 0.0002 s/iter. Total: 0.1407 s/iter. ETA=0:15:54
# [09/22 11:32:04 d2.evaluation.evaluator]: Inference done 5237/11981. Dataloading: 0.0014 s/iter. Inference: 0.1390 s/iter. Eval: 0.0002 s/iter. Total: 0.1407 s/iter. ETA=0:15:49
# [09/22 11:32:09 d2.evaluation.evaluator]: Inference done 5273/11981. Dataloading: 0.0014 s/iter. Inference: 0.1390 s/iter. Eval: 0.0002 s/iter. Total: 0.1408 s/iter. ETA=0:15:44
# [09/22 11:32:14 d2.evaluation.evaluator]: Inference done 5309/11981. Dataloading: 0.0014 s/iter. Inference: 0.1390 s/iter. Eval: 0.0002 s/iter. Total: 0.1408 s/iter. ETA=0:15:39
# [09/22 11:32:20 d2.evaluation.evaluator]: Inference done 5345/11981. Dataloading: 0.0014 s/iter. Inference: 0.1391 s/iter. Eval: 0.0002 s/iter. Total: 0.1408 s/iter. ETA=0:15:34
# [09/22 11:32:25 d2.evaluation.evaluator]: Inference done 5381/11981. Dataloading: 0.0014 s/iter. Inference: 0.1391 s/iter. Eval: 0.0002 s/iter. Total: 0.1408 s/iter. ETA=0:15:29
# [09/22 11:32:30 d2.evaluation.evaluator]: Inference done 5417/11981. Dataloading: 0.0014 s/iter. Inference: 0.1391 s/iter. Eval: 0.0002 s/iter. Total: 0.1408 s/iter. ETA=0:15:24
# [09/22 11:32:35 d2.evaluation.evaluator]: Inference done 5453/11981. Dataloading: 0.0014 s/iter. Inference: 0.1391 s/iter. Eval: 0.0002 s/iter. Total: 0.1408 s/iter. ETA=0:15:19
# [09/22 11:32:40 d2.evaluation.evaluator]: Inference done 5489/11981. Dataloading: 0.0014 s/iter. Inference: 0.1391 s/iter. Eval: 0.0002 s/iter. Total: 0.1408 s/iter. ETA=0:15:14
# [09/22 11:32:45 d2.evaluation.evaluator]: Inference done 5525/11981. Dataloading: 0.0014 s/iter. Inference: 0.1391 s/iter. Eval: 0.0002 s/iter. Total: 0.1408 s/iter. ETA=0:15:09
# [09/22 11:32:50 d2.evaluation.evaluator]: Inference done 5561/11981. Dataloading: 0.0014 s/iter. Inference: 0.1391 s/iter. Eval: 0.0002 s/iter. Total: 0.1408 s/iter. ETA=0:15:04
# [09/22 11:32:55 d2.evaluation.evaluator]: Inference done 5597/11981. Dataloading: 0.0014 s/iter. Inference: 0.1391 s/iter. Eval: 0.0002 s/iter. Total: 0.1408 s/iter. ETA=0:14:59
# [09/22 11:33:01 d2.evaluation.evaluator]: Inference done 5633/11981. Dataloading: 0.0014 s/iter. Inference: 0.1391 s/iter. Eval: 0.0002 s/iter. Total: 0.1408 s/iter. ETA=0:14:54
# [09/22 11:33:06 d2.evaluation.evaluator]: Inference done 5669/11981. Dataloading: 0.0014 s/iter. Inference: 0.1391 s/iter. Eval: 0.0002 s/iter. Total: 0.1409 s/iter. ETA=0:14:49
# [09/22 11:33:11 d2.evaluation.evaluator]: Inference done 5705/11981. Dataloading: 0.0014 s/iter. Inference: 0.1391 s/iter. Eval: 0.0002 s/iter. Total: 0.1409 s/iter. ETA=0:14:44
# [09/22 11:33:16 d2.evaluation.evaluator]: Inference done 5741/11981. Dataloading: 0.0014 s/iter. Inference: 0.1391 s/iter. Eval: 0.0002 s/iter. Total: 0.1409 s/iter. ETA=0:14:39
# [09/22 11:33:21 d2.evaluation.evaluator]: Inference done 5777/11981. Dataloading: 0.0014 s/iter. Inference: 0.1392 s/iter. Eval: 0.0002 s/iter. Total: 0.1409 s/iter. ETA=0:14:33
# [09/22 11:33:26 d2.evaluation.evaluator]: Inference done 5813/11981. Dataloading: 0.0014 s/iter. Inference: 0.1392 s/iter. Eval: 0.0002 s/iter. Total: 0.1409 s/iter. ETA=0:14:28
# [09/22 11:33:31 d2.evaluation.evaluator]: Inference done 5849/11981. Dataloading: 0.0014 s/iter. Inference: 0.1392 s/iter. Eval: 0.0002 s/iter. Total: 0.1409 s/iter. ETA=0:14:23
# [09/22 11:33:36 d2.evaluation.evaluator]: Inference done 5885/11981. Dataloading: 0.0014 s/iter. Inference: 0.1392 s/iter. Eval: 0.0002 s/iter. Total: 0.1409 s/iter. ETA=0:14:18
# [09/22 11:33:41 d2.evaluation.evaluator]: Inference done 5921/11981. Dataloading: 0.0014 s/iter. Inference: 0.1392 s/iter. Eval: 0.0002 s/iter. Total: 0.1409 s/iter. ETA=0:14:13
# [09/22 11:33:47 d2.evaluation.evaluator]: Inference done 5957/11981. Dataloading: 0.0014 s/iter. Inference: 0.1392 s/iter. Eval: 0.0002 s/iter. Total: 0.1409 s/iter. ETA=0:14:08
# [09/22 11:33:52 d2.evaluation.evaluator]: Inference done 5993/11981. Dataloading: 0.0014 s/iter. Inference: 0.1392 s/iter. Eval: 0.0002 s/iter. Total: 0.1409 s/iter. ETA=0:14:03
# [09/22 11:33:57 d2.evaluation.evaluator]: Inference done 6029/11981. Dataloading: 0.0014 s/iter. Inference: 0.1392 s/iter. Eval: 0.0002 s/iter. Total: 0.1409 s/iter. ETA=0:13:58
# [09/22 11:34:02 d2.evaluation.evaluator]: Inference done 6065/11981. Dataloading: 0.0014 s/iter. Inference: 0.1392 s/iter. Eval: 0.0002 s/iter. Total: 0.1409 s/iter. ETA=0:13:53
# [09/22 11:34:07 d2.evaluation.evaluator]: Inference done 6101/11981. Dataloading: 0.0014 s/iter. Inference: 0.1392 s/iter. Eval: 0.0002 s/iter. Total: 0.1409 s/iter. ETA=0:13:48
# [09/22 11:34:12 d2.evaluation.evaluator]: Inference done 6137/11981. Dataloading: 0.0014 s/iter. Inference: 0.1392 s/iter. Eval: 0.0002 s/iter. Total: 0.1409 s/iter. ETA=0:13:43
# [09/22 11:34:17 d2.evaluation.evaluator]: Inference done 6173/11981. Dataloading: 0.0014 s/iter. Inference: 0.1392 s/iter. Eval: 0.0002 s/iter. Total: 0.1410 s/iter. ETA=0:13:38
# [09/22 11:34:22 d2.evaluation.evaluator]: Inference done 6209/11981. Dataloading: 0.0014 s/iter. Inference: 0.1392 s/iter. Eval: 0.0002 s/iter. Total: 0.1410 s/iter. ETA=0:13:33
# [09/22 11:34:27 d2.evaluation.evaluator]: Inference done 6245/11981. Dataloading: 0.0014 s/iter. Inference: 0.1392 s/iter. Eval: 0.0002 s/iter. Total: 0.1410 s/iter. ETA=0:13:28
# [09/22 11:34:33 d2.evaluation.evaluator]: Inference done 6281/11981. Dataloading: 0.0014 s/iter. Inference: 0.1393 s/iter. Eval: 0.0002 s/iter. Total: 0.1410 s/iter. ETA=0:13:23
# [09/22 11:34:38 d2.evaluation.evaluator]: Inference done 6317/11981. Dataloading: 0.0014 s/iter. Inference: 0.1393 s/iter. Eval: 0.0002 s/iter. Total: 0.1410 s/iter. ETA=0:13:18
# [09/22 11:34:43 d2.evaluation.evaluator]: Inference done 6353/11981. Dataloading: 0.0014 s/iter. Inference: 0.1393 s/iter. Eval: 0.0002 s/iter. Total: 0.1410 s/iter. ETA=0:13:13
# [09/22 11:34:48 d2.evaluation.evaluator]: Inference done 6389/11981. Dataloading: 0.0014 s/iter. Inference: 0.1393 s/iter. Eval: 0.0002 s/iter. Total: 0.1410 s/iter. ETA=0:13:08
# [09/22 11:34:53 d2.evaluation.evaluator]: Inference done 6425/11981. Dataloading: 0.0014 s/iter. Inference: 0.1393 s/iter. Eval: 0.0002 s/iter. Total: 0.1410 s/iter. ETA=0:13:03
# [09/22 11:34:58 d2.evaluation.evaluator]: Inference done 6461/11981. Dataloading: 0.0014 s/iter. Inference: 0.1393 s/iter. Eval: 0.0002 s/iter. Total: 0.1410 s/iter. ETA=0:12:58
# [09/22 11:35:03 d2.evaluation.evaluator]: Inference done 6497/11981. Dataloading: 0.0014 s/iter. Inference: 0.1393 s/iter. Eval: 0.0002 s/iter. Total: 0.1410 s/iter. ETA=0:12:53
# [09/22 11:35:08 d2.evaluation.evaluator]: Inference done 6533/11981. Dataloading: 0.0014 s/iter. Inference: 0.1393 s/iter. Eval: 0.0002 s/iter. Total: 0.1410 s/iter. ETA=0:12:48
# [09/22 11:35:14 d2.evaluation.evaluator]: Inference done 6569/11981. Dataloading: 0.0014 s/iter. Inference: 0.1393 s/iter. Eval: 0.0002 s/iter. Total: 0.1410 s/iter. ETA=0:12:43
# [09/22 11:35:19 d2.evaluation.evaluator]: Inference done 6605/11981. Dataloading: 0.0014 s/iter. Inference: 0.1393 s/iter. Eval: 0.0002 s/iter. Total: 0.1410 s/iter. ETA=0:12:38
# [09/22 11:35:24 d2.evaluation.evaluator]: Inference done 6641/11981. Dataloading: 0.0014 s/iter. Inference: 0.1393 s/iter. Eval: 0.0002 s/iter. Total: 0.1410 s/iter. ETA=0:12:33
# [09/22 11:35:29 d2.evaluation.evaluator]: Inference done 6677/11981. Dataloading: 0.0014 s/iter. Inference: 0.1393 s/iter. Eval: 0.0002 s/iter. Total: 0.1410 s/iter. ETA=0:12:28
# [09/22 11:35:34 d2.evaluation.evaluator]: Inference done 6713/11981. Dataloading: 0.0014 s/iter. Inference: 0.1393 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:12:23
# [09/22 11:35:39 d2.evaluation.evaluator]: Inference done 6749/11981. Dataloading: 0.0014 s/iter. Inference: 0.1393 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:12:18
# [09/22 11:35:44 d2.evaluation.evaluator]: Inference done 6785/11981. Dataloading: 0.0014 s/iter. Inference: 0.1393 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:12:12
# [09/22 11:35:49 d2.evaluation.evaluator]: Inference done 6821/11981. Dataloading: 0.0014 s/iter. Inference: 0.1393 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:12:07
# [09/22 11:35:54 d2.evaluation.evaluator]: Inference done 6857/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:12:02
# [09/22 11:36:00 d2.evaluation.evaluator]: Inference done 6893/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:11:57
# [09/22 11:36:05 d2.evaluation.evaluator]: Inference done 6929/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:11:52
# [09/22 11:36:10 d2.evaluation.evaluator]: Inference done 6965/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:11:47
# [09/22 11:36:15 d2.evaluation.evaluator]: Inference done 7001/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:11:42
# [09/22 11:36:20 d2.evaluation.evaluator]: Inference done 7037/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:11:37
# [09/22 11:36:25 d2.evaluation.evaluator]: Inference done 7073/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:11:32
# [09/22 11:36:30 d2.evaluation.evaluator]: Inference done 7109/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:11:27
# [09/22 11:36:35 d2.evaluation.evaluator]: Inference done 7145/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:11:22
# [09/22 11:36:41 d2.evaluation.evaluator]: Inference done 7181/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:11:17
# [09/22 11:36:46 d2.evaluation.evaluator]: Inference done 7217/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:11:12
# [09/22 11:36:51 d2.evaluation.evaluator]: Inference done 7253/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:11:07
# [09/22 11:36:56 d2.evaluation.evaluator]: Inference done 7289/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:11:02
# [09/22 11:37:01 d2.evaluation.evaluator]: Inference done 7325/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:10:57
# [09/22 11:37:06 d2.evaluation.evaluator]: Inference done 7361/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1411 s/iter. ETA=0:10:52
# [09/22 11:37:11 d2.evaluation.evaluator]: Inference done 7397/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:10:47
# [09/22 11:37:16 d2.evaluation.evaluator]: Inference done 7433/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:10:41
# [09/22 11:37:21 d2.evaluation.evaluator]: Inference done 7469/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:10:36
# [09/22 11:37:27 d2.evaluation.evaluator]: Inference done 7505/11981. Dataloading: 0.0014 s/iter. Inference: 0.1394 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:10:31
# [09/22 11:37:32 d2.evaluation.evaluator]: Inference done 7541/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:10:26
# [09/22 11:37:37 d2.evaluation.evaluator]: Inference done 7577/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:10:21
# [09/22 11:37:42 d2.evaluation.evaluator]: Inference done 7613/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:10:16
# [09/22 11:37:47 d2.evaluation.evaluator]: Inference done 7649/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:10:11
# [09/22 11:37:52 d2.evaluation.evaluator]: Inference done 7685/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:10:06
# [09/22 11:37:57 d2.evaluation.evaluator]: Inference done 7721/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:10:01
# [09/22 11:38:02 d2.evaluation.evaluator]: Inference done 7757/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:09:56
# [09/22 11:38:08 d2.evaluation.evaluator]: Inference done 7793/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:09:51
# [09/22 11:38:13 d2.evaluation.evaluator]: Inference done 7829/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:09:46
# [09/22 11:38:18 d2.evaluation.evaluator]: Inference done 7865/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:09:41
# [09/22 11:38:23 d2.evaluation.evaluator]: Inference done 7901/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:09:36
# [09/22 11:38:28 d2.evaluation.evaluator]: Inference done 7937/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:09:31
# [09/22 11:38:33 d2.evaluation.evaluator]: Inference done 7973/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:09:26
# [09/22 11:38:38 d2.evaluation.evaluator]: Inference done 8009/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:09:20
# [09/22 11:38:43 d2.evaluation.evaluator]: Inference done 8045/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:09:15
# [09/22 11:38:48 d2.evaluation.evaluator]: Inference done 8081/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:09:10
# [09/22 11:38:54 d2.evaluation.evaluator]: Inference done 8117/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:09:05
# [09/22 11:38:59 d2.evaluation.evaluator]: Inference done 8153/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:09:00
# [09/22 11:39:04 d2.evaluation.evaluator]: Inference done 8189/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1412 s/iter. ETA=0:08:55
# [09/22 11:39:09 d2.evaluation.evaluator]: Inference done 8225/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:08:50
# [09/22 11:39:14 d2.evaluation.evaluator]: Inference done 8261/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:08:45
# [09/22 11:39:19 d2.evaluation.evaluator]: Inference done 8297/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:08:40
# [09/22 11:39:24 d2.evaluation.evaluator]: Inference done 8333/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:08:35
# [09/22 11:39:29 d2.evaluation.evaluator]: Inference done 8369/11981. Dataloading: 0.0014 s/iter. Inference: 0.1395 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:08:30
# [09/22 11:39:35 d2.evaluation.evaluator]: Inference done 8405/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:08:25
# [09/22 11:39:40 d2.evaluation.evaluator]: Inference done 8441/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:08:20
# [09/22 11:39:45 d2.evaluation.evaluator]: Inference done 8477/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:08:15
# [09/22 11:39:50 d2.evaluation.evaluator]: Inference done 8513/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:08:09
# [09/22 11:39:55 d2.evaluation.evaluator]: Inference done 8549/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:08:04
# [09/22 11:40:00 d2.evaluation.evaluator]: Inference done 8585/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:07:59
# [09/22 11:40:05 d2.evaluation.evaluator]: Inference done 8621/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:07:54
# [09/22 11:40:10 d2.evaluation.evaluator]: Inference done 8657/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:07:49
# [09/22 11:40:15 d2.evaluation.evaluator]: Inference done 8693/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:07:44
# [09/22 11:40:21 d2.evaluation.evaluator]: Inference done 8729/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:07:39
# [09/22 11:40:26 d2.evaluation.evaluator]: Inference done 8765/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:07:34
# [09/22 11:40:31 d2.evaluation.evaluator]: Inference done 8801/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:07:29
# [09/22 11:40:36 d2.evaluation.evaluator]: Inference done 8837/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:07:24
# [09/22 11:40:41 d2.evaluation.evaluator]: Inference done 8873/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:07:19
# [09/22 11:40:46 d2.evaluation.evaluator]: Inference done 8909/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:07:14
# [09/22 11:40:51 d2.evaluation.evaluator]: Inference done 8945/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:07:09
# [09/22 11:40:56 d2.evaluation.evaluator]: Inference done 8981/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:07:03
# [09/22 11:41:02 d2.evaluation.evaluator]: Inference done 9017/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:06:58
# [09/22 11:41:07 d2.evaluation.evaluator]: Inference done 9053/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:06:53
# [09/22 11:41:12 d2.evaluation.evaluator]: Inference done 9089/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:06:48
# [09/22 11:41:17 d2.evaluation.evaluator]: Inference done 9125/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:06:43
# [09/22 11:41:22 d2.evaluation.evaluator]: Inference done 9161/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:06:38
# [09/22 11:41:27 d2.evaluation.evaluator]: Inference done 9197/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1413 s/iter. ETA=0:06:33
# [09/22 11:41:32 d2.evaluation.evaluator]: Inference done 9233/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:06:28
# [09/22 11:41:37 d2.evaluation.evaluator]: Inference done 9269/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:06:23
# [09/22 11:41:42 d2.evaluation.evaluator]: Inference done 9305/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:06:18
# [09/22 11:41:48 d2.evaluation.evaluator]: Inference done 9341/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:06:13
# [09/22 11:41:53 d2.evaluation.evaluator]: Inference done 9377/11981. Dataloading: 0.0014 s/iter. Inference: 0.1396 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:06:08
# [09/22 11:41:58 d2.evaluation.evaluator]: Inference done 9413/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:06:03
# [09/22 11:42:03 d2.evaluation.evaluator]: Inference done 9449/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:05:57
# [09/22 11:42:08 d2.evaluation.evaluator]: Inference done 9485/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:05:52
# [09/22 11:42:13 d2.evaluation.evaluator]: Inference done 9521/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:05:47
# [09/22 11:42:18 d2.evaluation.evaluator]: Inference done 9557/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:05:42
# [09/22 11:42:23 d2.evaluation.evaluator]: Inference done 9593/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:05:37
# [09/22 11:42:29 d2.evaluation.evaluator]: Inference done 9629/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:05:32
# [09/22 11:42:34 d2.evaluation.evaluator]: Inference done 9665/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:05:27
# [09/22 11:42:39 d2.evaluation.evaluator]: Inference done 9701/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:05:22
# [09/22 11:42:44 d2.evaluation.evaluator]: Inference done 9737/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:05:17
# [09/22 11:42:49 d2.evaluation.evaluator]: Inference done 9773/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:05:12
# [09/22 11:42:54 d2.evaluation.evaluator]: Inference done 9809/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:05:07
# [09/22 11:42:59 d2.evaluation.evaluator]: Inference done 9845/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:05:02
# [09/22 11:43:04 d2.evaluation.evaluator]: Inference done 9881/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:04:56
# [09/22 11:43:09 d2.evaluation.evaluator]: Inference done 9917/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:04:51
# [09/22 11:43:15 d2.evaluation.evaluator]: Inference done 9953/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:04:46
# [09/22 11:43:20 d2.evaluation.evaluator]: Inference done 9989/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:04:41
# [09/22 11:43:25 d2.evaluation.evaluator]: Inference done 10025/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:04:36
# [09/22 11:43:30 d2.evaluation.evaluator]: Inference done 10061/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:04:31
# [09/22 11:43:35 d2.evaluation.evaluator]: Inference done 10097/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:04:26
# [09/22 11:43:40 d2.evaluation.evaluator]: Inference done 10133/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:04:21
# [09/22 11:43:45 d2.evaluation.evaluator]: Inference done 10169/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:04:16
# [09/22 11:43:50 d2.evaluation.evaluator]: Inference done 10205/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:04:11
# [09/22 11:43:56 d2.evaluation.evaluator]: Inference done 10241/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:04:06
# [09/22 11:44:01 d2.evaluation.evaluator]: Inference done 10277/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:04:01
# [09/22 11:44:06 d2.evaluation.evaluator]: Inference done 10313/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:03:55
# [09/22 11:44:11 d2.evaluation.evaluator]: Inference done 10349/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:03:50
# [09/22 11:44:16 d2.evaluation.evaluator]: Inference done 10385/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:03:45
# [09/22 11:44:21 d2.evaluation.evaluator]: Inference done 10421/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:03:40
# [09/22 11:44:26 d2.evaluation.evaluator]: Inference done 10457/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:03:35
# [09/22 11:44:31 d2.evaluation.evaluator]: Inference done 10493/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1414 s/iter. ETA=0:03:30
# [09/22 11:44:36 d2.evaluation.evaluator]: Inference done 10529/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:03:25
# [09/22 11:44:42 d2.evaluation.evaluator]: Inference done 10565/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:03:20
# [09/22 11:44:47 d2.evaluation.evaluator]: Inference done 10601/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:03:15
# [09/22 11:44:52 d2.evaluation.evaluator]: Inference done 10637/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:03:10
# [09/22 11:44:57 d2.evaluation.evaluator]: Inference done 10673/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:03:05
# [09/22 11:45:02 d2.evaluation.evaluator]: Inference done 10709/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:02:59
# [09/22 11:45:07 d2.evaluation.evaluator]: Inference done 10745/11981. Dataloading: 0.0014 s/iter. Inference: 0.1397 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:02:54
# [09/22 11:45:12 d2.evaluation.evaluator]: Inference done 10781/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:02:49
# [09/22 11:45:17 d2.evaluation.evaluator]: Inference done 10817/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:02:44
# [09/22 11:45:23 d2.evaluation.evaluator]: Inference done 10853/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:02:39
# [09/22 11:45:28 d2.evaluation.evaluator]: Inference done 10889/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:02:34
# [09/22 11:45:33 d2.evaluation.evaluator]: Inference done 10925/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:02:29
# [09/22 11:45:38 d2.evaluation.evaluator]: Inference done 10961/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:02:24
# [09/22 11:45:43 d2.evaluation.evaluator]: Inference done 10997/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:02:19
# [09/22 11:45:48 d2.evaluation.evaluator]: Inference done 11033/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:02:14
# [09/22 11:45:53 d2.evaluation.evaluator]: Inference done 11069/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:02:09
# [09/22 11:45:58 d2.evaluation.evaluator]: Inference done 11105/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:02:03
# [09/22 11:46:03 d2.evaluation.evaluator]: Inference done 11141/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:01:58
# [09/22 11:46:09 d2.evaluation.evaluator]: Inference done 11177/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:01:53
# [09/22 11:46:14 d2.evaluation.evaluator]: Inference done 11213/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:01:48
# [09/22 11:46:19 d2.evaluation.evaluator]: Inference done 11249/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:01:43
# [09/22 11:46:24 d2.evaluation.evaluator]: Inference done 11285/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:01:38
# [09/22 11:46:29 d2.evaluation.evaluator]: Inference done 11321/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:01:33
# [09/22 11:46:34 d2.evaluation.evaluator]: Inference done 11357/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:01:28
# [09/22 11:46:39 d2.evaluation.evaluator]: Inference done 11393/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:01:23
# [09/22 11:46:44 d2.evaluation.evaluator]: Inference done 11429/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:01:18
# [09/22 11:46:50 d2.evaluation.evaluator]: Inference done 11465/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:01:13
# [09/22 11:46:55 d2.evaluation.evaluator]: Inference done 11501/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:01:07
# [09/22 11:47:00 d2.evaluation.evaluator]: Inference done 11537/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:01:02
# [09/22 11:47:05 d2.evaluation.evaluator]: Inference done 11573/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:00:57
# [09/22 11:47:10 d2.evaluation.evaluator]: Inference done 11609/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:00:52
# [09/22 11:47:15 d2.evaluation.evaluator]: Inference done 11645/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:00:47
# [09/22 11:47:20 d2.evaluation.evaluator]: Inference done 11681/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:00:42
# [09/22 11:47:25 d2.evaluation.evaluator]: Inference done 11717/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:00:37
# [09/22 11:47:31 d2.evaluation.evaluator]: Inference done 11753/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:00:32
# [09/22 11:47:36 d2.evaluation.evaluator]: Inference done 11789/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:00:27
# [09/22 11:47:41 d2.evaluation.evaluator]: Inference done 11825/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:00:22
# [09/22 11:47:46 d2.evaluation.evaluator]: Inference done 11861/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:00:16
# [09/22 11:47:51 d2.evaluation.evaluator]: Inference done 11897/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:00:11
# [09/22 11:47:56 d2.evaluation.evaluator]: Inference done 11933/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:00:06
# [09/22 11:48:01 d2.evaluation.evaluator]: Inference done 11969/11981. Dataloading: 0.0014 s/iter. Inference: 0.1398 s/iter. Eval: 0.0002 s/iter. Total: 0.1415 s/iter. ETA=0:00:01
# [09/22 11:48:03 d2.evaluation.evaluator]: Total inference time: 0:28:15.127959 (0.141544 s / iter per device, on 1 devices)
# [09/22 11:48:03 d2.evaluation.evaluator]: Total inference pure compute time: 0:27:54 (0.139821 s / iter per device, on 1 devices)
# [09/22 11:48:03 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [09/22 11:48:03 d2.evaluation.coco_evaluation]: Saving results to ./out/coco_instances_results.json
# [09/22 11:48:03 d2.evaluation.coco_evaluation]: Annotations are not available for evaluation.
# Number of predictions remaining: 28214/28999
# [09/22 11:48:23 d2.data.datasets.coco]: Loaded 11981 images in COCO format from /content/out/8-ralphbreaks_coco_format.json
# Done! Saved 28214
